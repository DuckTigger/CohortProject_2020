# %%
from rnn_helper import RNNHelper, RNN

# %% [markdown]
# In the file `rnn_helper.py` we defined a recurrent neural network and the functions necesarry to train it on the H2 data.
#
# Below we will show the results for training multiple RNNs on new values of R.

# %%
rnn_helper = RNNHelper(epochs=9, verbose=True)
rnn_helper.iterate_over_r()
# Out:
# R = 0.2
# Start of epoch 0
# Step: 0, loss: 0.7550265192985535
# Energy: 0.0
# Accuracy: 0.0
# Step: 100, loss: 0.002903017681092024
# Energy: 0.15039999999999987
# Accuracy: 0.9570828116783809
# Step: 200, loss: 0.0012533508706837893
# Energy: 0.15039999999999987
# Accuracy: 0.9570828116783809
# Step: 300, loss: 0.0017742023337632418
# Energy: 0.15039999999999987
# Accuracy: 0.9570828116783809
# Step: 400, loss: 0.0010428344830870628
# Energy: 0.15039999999999987
# Accuracy: 0.9570828116783809
# Step: 500, loss: 0.0003737182996701449
# Energy: 0.15039999999999987
# Accuracy: 0.9570828116783809
# Step: 600, loss: 0.0002396435447735712
# Energy: 0.15039999999999987
# Accuracy: 0.9570828116783809
# Start of epoch 1
# Step: 0, loss: 0.00017459431546740234
# Energy: 0.15039999999999987
# Accuracy: 0.9570828116783809
# Step: 100, loss: 0.00013669420150108635
# Energy: 0.15039999999999987
# Accuracy: 0.9570828116783809
# Step: 200, loss: 0.00010758201824501157
# ...
